# %% [markdown]
# # **Import Libraries and CSV**

# %%
import numpy as np # Multi-dimensional arrays
import pandas as pd # Data manipulation and analysis
import matplotlib.pyplot as plt # Visualising data
# %matplotlib inline
import seaborn as sns # Visualising data

# %%
from google.colab import files
uploaded = files.upload()

# Opens a file selector dialog to upload a file from my local machine to Google Colab

uploaded = files.upload()
# Out:
#      <input type="file" id="files-8a85d63e-166a-468d-9e64-f22d5233df4b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8a85d63e-166a-468d-9e64-f22d5233df4b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# Reads the uploaded CSV file into a pandas DataFrame using the specified encoding

df = pd.read_csv(io.BytesIO(uploaded['Diwali Sales Data.csv']), encoding='latin1')

# %% [markdown]
# # **Data Cleaning**

# %%
# Displays the number of rows and columns in the DataFrame

df.shape
# Out:
# (11251, 15)

# %%
# Displays the first 5 rows in the DataFrame

df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
# Displays the last 5 rows in the DataFrame

df.tail()
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# 11246     Maharashtra   Western     Chemical           Office       4   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary       3   367.0
# 11248  Madhya Pradesh   Central      Textile           Office       4   213.0
# 11249       Karnataka  Southern  Agriculture           Office       3   206.0
# 11250     Maharashtra   Western   Healthcare           Office       3   188.0
#
#        Status  unnamed1
# ...

# %%
# Displays a summary of the DataFrame, including the number of non-null values and the data type of each column

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
# Drop unrelated/blank columns
# axis1=1 argument used so that it drops the entire column (axis=0 is for dropping a row)
# inplace=True means that the changes made by the drop method will be applied to the original DataFrame instead of creating a new one

df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
# Checks for missing/null values in the DataFrame and returns a boolean DataFrame of the same shape

pd.isnull(df)
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
# Returns the number of missing/null values in each column of the DataFrame

pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
# Checks the total number of rows and columns

df.shape
# Out:
# (11251, 13)

# %%
# Drop null values

df.dropna(inplace=True)

# %%
df.shape
# Out:
# (11239, 13)

# %%
# Change data type

df['Amount'] = df['Amount'].astype(int)

# %%
# Check datatype of a specific column

df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# Renamed column name for demonstration purpose and did not apply the inplace=True argument

df.rename(columns= {'Marital_Status': 'Shaadi'})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Shaadi  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28       0
# 1      1000732       Kartik  P00110942      F     26-35   35       1
# 2      1001990        Bindu  P00118542      F     26-35   35       1
# 3      1001425       Sudevi  P00237842      M      0-17   16       0
# 4      1000588         Joni  P00057942      M     26-35   28       1
# ...        ...          ...        ...    ...       ...  ...     ...
# 11246  1000695      Manning  P00296942      M     18-25   19       1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33       0
# 11248  1001209        Oshin  P00201342      F     36-45   40       0
# 11249  1004023       Noonan  P00059442      M     36-45   37       0
# 11250  1002744      Brumley  P00281742      F     18-25   19       0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
# Generates summary statistics of the DataFrame

df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# Use describe() for specific columns containing only numeric values

df[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# **Total Purchase and Amount Spent by Gender**

# %%
# Create a count plot with 'Gender' on the x-axis using the data in the df DataFrame

ax = sns.countplot(data = df, x = 'Gender')

# Add labels above each bar displaying the count for each gender

for bars in ax.containers:
  ax.bar_label(bars)

# %%
df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
# Out:
#   Gender    Amount
# 0      F  74335853
# 1      M  31913276

# %%
# Group the data by 'Gender', calculate the sum of the 'Amount' column for each group, and sort the resulting DataFrame in descending order by 'Amount

sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# Create a bar plot with 'Gender' on the x-axis and 'Amount' on the y-axis using the data in the sales_gen DataFrame

sns.barplot(x = 'Gender', y = 'Amount', data = sales_gen)

# Add labels above each bar displaying the sum of amount for each gender as integers

for i, row in sales_gen.iterrows():
    plt.annotate(f"{int(row['Amount'])}", xy=(i, row['Amount']), ha='center', va='bottom')

# %% [markdown]
# *From the above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %% [markdown]
# **Total Purchase and Amount Spent by Age**

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group', y = 'Amount', data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# *From the above graphs we can see that most of the buyers are of the age group between 26-35 and females*

# %% [markdown]
# **Orders by State**

# %%
# Total number of orders from top 10 states

orders_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(18,5)})
sns.barplot(x = 'State', y = 'Orders', data = orders_state)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
# Total number of amount/sales from top 10 states

sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(18,5)})
sns.barplot(x = 'State', y = 'Amount', data = sales_state)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# *From the above graphs we can see that most of the orders and total sales/amount are from Uttar Pradesh, Maharastra and Karnataka respectively*

# %% [markdown]
# **Total Purchase and Amoun Spent by Marital Status**

# %%
ax = sns.countplot(data = df, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(1,5)})
for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_marital = df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(x = 'Marital_Status', y = 'Amount', hue = 'Gender', data = sales_marital)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# *From the above graphs we can see that most of the buyers are married (woman) and they have high purchasing power*

# %% [markdown]
# **Total Purchase and Amount Spent by Occupation**

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Occupation')

for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_occupation = df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(x = 'Occupation', y = 'Amount', data = sales_occupation)
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# *From the above graphs we can see that most of the buyers are working in the IT, Healthcare and Aviation sector*

# %% [markdown]
# **Total Purchase and Amount Spent by Product Category**

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Product_Category')

ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

for bars in ax.containers:
  ax.bar_label(bars)

# %%
sales_category = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
ax = sns.barplot(x = 'Product_Category', y = 'Amount', data = sales_category)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90);

# %% [markdown]
# *From the above graphs we can see that most of the sold products are from Food, Clothing and Electronics category*

# %% [markdown]
# **Top 10 Products Sold**

# %%
fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %% [markdown]
# **Conclusion**

# %% [markdown]
# *Married women between the ages of 26 and 35 who live in Uttar Pradesh, Maharashtra, or Karnataka and work in the IT, healthcare, or aviation industries are more likely to purchase products in the food, clothing, and electronics categories*
